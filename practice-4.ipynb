# %%
import seaborn as sns
import pandas as pd

# %%
df=pd.read_csv('Datasets/iris.csv')

# %%
df.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import seaborn as sns

sns.kdeplot(data=df,x='Petal.Width',hue='Species',fill=True)
# Out:
# <Axes: xlabel='Petal.Width', ylabel='Density'>

# %%
df2=pd.read_csv('Datasets/titanic.csv')

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
sns.kdeplot(data=df2,x='Age',hue='Survived')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(data=df,x='Petal.Width',hue='Species')
sns.ecdfplot(data=df,x='Petal.Width',hue='Species')


# so cdf is used to check how much we are correct in our predictions
# Out:
# <Axes: xlabel='Petal.Width', ylabel='Density'>

# %% [markdown]
# 2D Density Plot(SO far we have practices 1D plots)

# %%
sns.jointplot(data=df,x='Petal.Length',y='Sepal.Length',kind='kde',fill=True,cbar=True)

# %%
df2['Age']
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %% [markdown]
# Standardizing Normal Distribution

# %%
x=(df2['Age']-df2['Age'].mean())/df2['Age'].std()

# %%
x
# Out:
# 0      0.298099
# 1      1.179547
# 2      2.237285
# 3     -0.230769
# 4     -0.583349
#          ...
# 413         NaN
# 414    0.615421
# 415    0.580163
# 416         NaN
# 417         NaN
# Name: Age, Length: 418, dtype: float64

# %%
sns.kdeplot(x=x,fill=True)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df2["Age"].skew()
# Out:
# 0.4573612871503845

# %%
#Finding putlier by finding data between mean+-3*std(Empritical rule)
df['Sepal.Length'].mean()+3*df['Sepal.Length'].std()
# Out:
# 8.327531717266922

# %%
df['Sepal.Length'].max()
# Out:
# 7.9

# %%
df[df['Sepal.Length']>7.8]
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 131           7.9          3.8           6.4          2.0  virginica
